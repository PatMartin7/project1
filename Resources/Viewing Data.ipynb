# %%
#Reader for Suicide File
import pandas as pd


csv_path = "reviseddata.csv"
suicide_df = pd.read_csv(csv_path, low_memory=False)
suicide_df
# Out:
#            Data Source World Development Indicators  \
# 0                  NaN                          NaN
# 1    Last Updated Date                    9/15/2021
# 2                  NaN                          NaN
# 3         Country Name                 Country Code
# 4                Aruba                          ABW
# ..                 ...                          ...
# 265             Kosovo                          XKX
# 266        Yemen, Rep.                          YEM
# 267       South Africa                          ZAF
# 268             Zambia                          ZMB
# 269           Zimbabwe                          ZWE
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# ...
